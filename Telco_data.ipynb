# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Plan

# %% [markdown]
# - Describe the project and goals.
#
# - Task out how you will work through the pipeline in as much detail as you need to keep on track.
#
# - Include a data dictionary to provide context for and explain your data.
#
# - Clearly state your starting hypotheses (and add the testing of these to your task list).

# %% [markdown]
# ______

# %% [markdown]
# Plan -
# ## Acquire

# %% [markdown]
# I acquire the data from the telco_churn SQL database using the function imported from the acquire.py file.

# %%
import acquire as a
df = a.new_telco_data()
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0016-QLJIS  Female               0     Yes        Yes      65
# 1     0017-DINOC    Male               0      No         No      54
# 2     0019-GFNTW  Female               0      No         No      56
# 3     0056-EPFBG    Male               0     Yes        Yes      20
# 4     0078-XZMHT    Male               0     Yes         No      72
# ...          ...     ...             ...     ...        ...     ...
# 7038  9962-BFPDU  Female               0     Yes        Yes       1
# 7039  9967-ATRFS  Female               0      No         No      19
# 7040  9970-QBCDA  Female               0      No         No       6
# 7041  9975-SKRNR    Male               0      No         No       1
# 7042  9986-BONCE  Female               0      No         No       4
#
#      phone_service    multiple_lines internet_service_type_id  \
# 0              Yes               Yes                        1
# ...

# %% [markdown]
# __________________________________

# %% [markdown]
# Plan - Acquire -
# ## Prepare

# %% [markdown]
# For this step, I will prepare the data and perform any cleaning necessary to make the data more usable for explorationa and analysis

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0016-QLJIS  Female               0     Yes        Yes      65
# 1  0017-DINOC    Male               0      No         No      54
# 2  0019-GFNTW  Female               0      No         No      56
# 3  0056-EPFBG    Male               0     Yes        Yes      20
# 4  0078-XZMHT    Male               0     Yes         No      72
#
#   phone_service    multiple_lines  internet_service_type_id online_security  \
# 0           Yes               Yes                         1             Yes
# 1            No  No phone service                         1             Yes
# 2            No  No phone service                         1             Yes
# 3            No  No phone service                         1             Yes
# 4           Yes               Yes                         1              No
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# ...

# %%
df.shape
# Out:
# (7043, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        senior_citizen       tenure  internet_service_type_id  \
# count     7043.000000  7043.000000               7043.000000
# mean         0.162147    32.371149                  1.872923
# std          0.368612    24.559481                  0.737796
# min          0.000000     0.000000                  1.000000
# 25%          0.000000     9.000000                  1.000000
# 50%          0.000000    29.000000                  2.000000
# 75%          0.000000    55.000000                  2.000000
# max          1.000000    72.000000                  3.000000
#
#        contract_type_id  payment_type_id  monthly_charges  contract_type_id  \
# count       7043.000000      7043.000000      7043.000000       7043.000000
# mean           1.690473         2.315633        64.761692          1.690473
# std            0.833755         1.148907        30.090047          0.833755
# min            1.000000         1.000000        18.250000          1.000000
# ...

# %% [markdown]
# **Immediate Takeaways**
#
# 1. Customer ID is not a useable feature, can be dropped
# 2. Create dummy vars for contract type, payment type, service type, contract type, multiple lines, and gender

# %%
# Use .describe with object columns.
list(df.columns)
for i in range(len(list(df.columns))):
    x = df[df[df.columns[i]].dtype == 'O']
print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
